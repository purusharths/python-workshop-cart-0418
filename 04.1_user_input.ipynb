# %% [markdown]
# # User inputs
# Sometimes you just have to make your user do something in your programs

# %%
last_jedi = input("Who was the last jedi?")
# Out:
# Who was the last jedi?Luke

# %%
last_jedi
# Out:
# 'Luke'

# %%
gps_lat = input("latitude: ")
gps_long = input("longitude: ")
# Out:
# latitude: 26.0874
# longitude: 36.5987

# %%
type(gps_lat)
# Out:
# str

# %%
gps_lat = float(gps_lat)  #type conversion

# %%
gps_lat + 4
# Out:
# 30.0874

# %% [markdown]
# # Shortcut

# %%
gps_lat = float(input("latitude: "))
gps_long = float(input("longitude: "))
# Out:
# latitude: 26.597
# longitude: 56.789

# %%
type(gps_lat)
# Out:
# float
