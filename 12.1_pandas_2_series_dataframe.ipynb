# %%
import pandas as pd

# %%
table = pd.DataFrame(columns=('name','age'))

# %%
table
# Out:
# Empty DataFrame
# Columns: [name, age]
# Index: []

# %%
table.loc[1] = "Dracrays", 15

# %%
table.loc[2] = "Potter, James", 20

# %%
table
# Out:
#             name age
# 1       Dracrays  15
# 2  Potter, James  20

# %%
table.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
table.head() # returns first five entries
# Out:
#             name age
# 1       Dracrays  15
# 2  Potter, James  20

# %%
table.tail() # returns last five entries
# Out:
#             name age
# 1       Dracrays  15
# 2  Potter, James  20

# %%
table.name
# Out:
# 1         Dracrays
# 2    Potter, James
# Name: name, dtype: object

# %%
table.age
# Out:
# 1    15
# 2    20
# Name: age, dtype: object

# %%
type(table.age)
# Out:
# pandas.core.series.Series

# %%
for i in table.age:
    print(i)
# Out:
# 15
# 20

# %%
table[table.age == 15]
# Out:
#        name age
# 1  Dracrays  15

# %% [markdown]
#  `Series` **-> 1D** <br>
#  `Dataframe` **-> 2D**

# %% [markdown]
# #### Series

# %%
 x = pd.Series([6,3,8,6])

# %%
x
# Out:
# 0    6
# 1    3
# 2    8
# 3    6
# dtype: int64

# %%
x[1]
# Out:
# 3

# %% [markdown]
# **Giving custom index**

# %%
x = pd.Series([6,3,8,6], index=["q","w","e","r"])

# %%
x
# Out:
# q    6
# w    3
# e    8
# r    6
# dtype: int64

# %%
x["w"] # compared to x[1]
# Out:
# 3

# %%
x.iloc[2] # but!
# Out:
# 8

# %%
x[["w","r"]]
# Out:
# w    3
# r    6
# dtype: int64

# %%
age = {"Captain 'Murica": 120, "Iron Man": 30, "Batman": 25, "Thor": 1000}

# %%
x = pd.Series(age)

# %%
x
# Out:
# Batman               25
# Captain 'Murica     120
# Iron Man             30
# Thor               1000
# dtype: int64

# %%
x["Batman"]
# Out:
# 25

# %% [markdown]
# > INDEX OF THE SERIES consists of the KEYs of the dictonary in SORTED order

# %% [markdown]
# ## DataFrame

# %%
data = {
    'name': ['Tim', 'Lim', 'Jim', 'Dim'],
    'age' : [21,42,84,126],
    'ZIP' : ['0011','1122','2233','3344']
}

# %%
x = pd.DataFrame(data)

# %%
x
# Out:
#     ZIP  age name
# 0  0011   21  Tim
# 1  1122   42  Lim
# 2  2233   84  Jim
# 3  3344  126  Dim

# %%
x = pd.DataFrame(data, columns=['name', 'age', 'ZIP']) # recommended

# %%
x
# Out:
#   name  age   ZIP
# 0  Tim   21  0011
# 1  Lim   42  1122
# 2  Jim   84  2233
# 3  Dim  126  3344

# %%
x["name"]
# Out:
# 0    Tim
# 1    Lim
# 2    Jim
# 3    Dim
# Name: name, dtype: object

# %%
x.name
# Out:
# 0    Tim
# 1    Lim
# 2    Jim
# 3    Dim
# Name: name, dtype: object

# %% [markdown]
# ### Re-indexing
# Re-indexing does not affects the relationship between data but rather reorders the data in a table. <br>
# For more info: https://stackoverflow.com/a/27238758/4593199

# %%
x = pd.Series([6,3,8,6], index=["q","w","e","r"])

# %%
x
# Out:
# q    6
# w    3
# e    8
# r    6
# dtype: int64

# %%
x.index
# Out:
# Index(['q', 'w', 'e', 'r'], dtype='object')

# %%
sorted(x.index)
# Out:
# ['e', 'q', 'r', 'w']

# %%
x.reindex(sorted(x.index)) #reindex takes new list as an argument according to which it'll create a new index.
# Out:
# e    8
# q    6
# r    6
# w    3
# dtype: int64

# %%
x
# Out:
# q    6
# w    3
# e    8
# r    6
# dtype: int64

# %% [markdown]
# ### Arithmetic Operations:
# According to index. If index dosen't match ->NaN

# %%
x = pd.Series([6,3,8,6], index=["q","w","e","r"])

# %%
y = pd.Series([7,3,5,7], index=["e","q","r","t"])

# %%
x+y
# Out:
# e    15.0
# q     9.0
# r    11.0
# t     NaN
# w     NaN
# dtype: float64
