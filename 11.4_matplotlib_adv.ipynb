# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1,300, 1000)
y = np.sin(x)
plt.figure(figsize=(50, 20))
plt.grid()
plt.axis.set_xticklabels(labels, fontsize='small')
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-ee7020a875ce> in <module>()
#       3 plt.figure(figsize=(50, 20))
#       4 plt.grid()
# ----> 5 plt.axis.set_xticklabels(labels, fontsize='small')
#       6 plt.plot(x,y)
#       7 plt.show()
#
# AttributeError: 'function' object has no attribute 'set_xticklabels'

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F1 = np.sin(2* X)
F2 = (2*X**5 + 4*X**4 - 4.8*X**3 + 1.2*X**2 + X + 1)*np.exp(-X**2)
# get the current axes, creating them if necessary:
ax = plt.gca()
# making the top and right spine invisible:
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
# moving bottom spine up to y=0 position:
ax.xaxis.set_ticks_position('bottom')
plt.xticks( np.arange(4), 
           ('Berlin', 'London', 'Hamburg', 'Toronto') )
ax.spines['bottom'].set_position(('data',0))
# moving left spine to the right to position x == 0:
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',1))
plt.plot(X, F1)
plt.plot(X, F2)
plt.show()

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
sin = np.sin(x)
cos = np.cos(x)
tan = np.tanh(x)
plt.plot(x,sin, 'r', label="$sin(x)$")
plt.plot(x,cos, 'y', label="cos")
plt.plot(x,tan, 'm', label="tan")
plt.xlabel("x - values")
plt.ylabel("y -values")
plt.axis()
plt.grid(which="both")
plt.title("e^x")
plt.legend(loc="best")
plt.show()
